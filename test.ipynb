# %%
from loguru import logger
import os
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load stock data
stock_file = 'C:/PP_stuff/stock/codes/MASTER/data/csi300/csi300_dl_train.pkl'
with open(stock_file, 'rb') as f:
    dl_train = pickle.load(f)

dl_train.data # a Pandas dataframe
# Out:
#                                    feature                     \
#                       ($close-$open)/$open ($high-$low)/$open
# datetime   instrument
# 2008-01-02 SH600000               0.566957           1.770685
#            SH600001               1.749363           2.853979
#            SH600004               3.000000           1.686718
#            SH600005              -1.352733           0.845277
#            SH600006               0.692366           0.579018
# ...                                    ...                ...
# 2020-03-31 SZ300144              -0.519907           0.381621
#            SZ300347              -0.798496           0.868896
#            SZ300408              -0.884044           0.154063
#            SZ300413               0.075304           0.427410
#            SZ300498               2.567887           1.258494
#
#                                                          \
#                       ($close-$open)/($high-$low+1e-12)
# ...

# %%
# dl_train.get_index()
count = pd.Series(index=dl_train.get_index()).groupby("datetime").size().values

type(count)

# count.tolist()
count[-50:]
# Out:
# C:\Users\xxkai\AppData\Local\Temp\ipykernel_28696\3923036286.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   count = pd.Series(index=dl_train.get_index()).groupby("datetime").size().values
# array([284, 284, 284, 284, 284, 284, 284, 284, 284, 284, 284, 284, 284,
#        284, 284, 284, 284, 284, 284, 284, 284, 284, 284, 284, 284, 284,
#        284, 283, 283, 283, 282, 282, 281, 281, 281, 282, 282, 282, 282,
#        281, 282, 282, 283, 283, 283, 283, 283, 283, 283, 283], dtype=int64)

# %%
df = dl_train.data
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# 12*300*220
# Out:
# 792000

# %%
# len(df.columns.to_list())

(df.columns.to_list())
# Out:
# [('feature', '($close-$open)/$open'),
#  ('feature', '($high-$low)/$open'),
#  ('feature', '($close-$open)/($high-$low+1e-12)'),
#  ('feature', '($high-Greater($open, $close))/$open'),
#  ('feature', '($high-Greater($open, $close))/($high-$low+1e-12)'),
#  ('feature', '(Less($open, $close)-$low)/$open'),
#  ('feature', '(Less($open, $close)-$low)/($high-$low+1e-12)'),
#  ('feature', '(2*$close-$high-$low)/$open'),
#  ('feature', '(2*$close-$high-$low)/($high-$low+1e-12)'),
#  ('feature', '$open/$close'),
#  ('feature', '$high/$close'),
#  ('feature', '$low/$close'),
#  ('feature', '$vwap/$close'),
#  ('feature', 'Ref($close, 5)/$close'),
#  ('feature', 'Ref($close, 10)/$close'),
#  ('feature', 'Ref($close, 20)/$close'),
#  ('feature', 'Ref($close, 30)/$close'),
#  ('feature', 'Ref($close, 60)/$close'),
#  ('feature', 'Mean($close, 5)/$close'),
#  ('feature', 'Mean($close, 10)/$close'),
#  ('feature', 'Mean($close, 20)/$close'),
#  ('feature', 'Mean($close, 30)/$close'),
# ...

# %%
# load stock data
stock_file = 'C:/PP_stuff/stock/codes/MASTER/data/csi300/csi300_dl_test.pkl'
with open(stock_file, 'rb') as f:
    dl_train = pickle.load(f)

dl_train.data # a Pandas dataframe
# Out:
#                                    feature                     \
#                       ($close-$open)/$open ($high-$low)/$open
# datetime   instrument
# 2020-06-17 SH600000               0.156989          -1.291258
#            SH600004               0.493149          -0.068597
#            SH600009              -0.542446          -0.488827
#            SH600011              -0.131334          -1.454761
#            SH600015               0.000000          -1.458679
# ...                                    ...                ...
# 2022-12-30 SZ300896              -0.167342          -0.359149
#            SZ300919              -2.304998           1.204258
#            SZ300957              -0.636793           0.094074
#            SZ300979              -0.398857          -0.366375
#            SZ300999               0.050214          -0.756356
#
#                                                          \
#                       ($close-$open)/($high-$low+1e-12)
# ...

# %%
dl_train.data.shape
# Out:
# (175491, 222)
